# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df_2015=pd.read_csv("2015.csv")
df_2016=pd.read_csv("2016.csv")
df_2017=pd.read_csv("2017.csv")
df_2018=pd.read_csv("2018.csv")
df_2019=pd.read_csv("2019.csv")

# %%
df_2015=df_2015.rename(columns={"Happiness Rank":"Happiness_Rank","Happiness Score":"Happiness_Score","Standard Error":"Standard_Error",
                                "Economy (GDP per Capita)":"GDP_per_Capita","Health (Life Expectancy)":"Healty","Trust (Government Corruption)":"Trust_to_Goverment","Dystopia Residual":"Dystopia_Residual"})

# %%
df_2015
# Out:
#          Country                           Region  Happiness_Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  GDP_per_Capita   Family   Healty  Freedom  \
# 0              7.587         1.39651  1.34951  0.94143  0.66557
# ...

# %%
df_2015=df_2015.drop(columns=["Standard_Error"],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13100/1247698945.py in <module>
# ----> 1 df_2015=df_2015.drop(columns=["Standard_Error"],axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df_2015.max(axis=0)
# Out:
# Country                           Zimbabwe
# Region                      Western Europe
# Happiness_Rank                         158
# Happiness_Score                      7.587
# Economy (GDP per Capita)           1.69042
# Family                             1.40223
# Healty                             1.02525
# Freedom                            0.66973
# Trust_to_Goverment                 0.55191
# Generosity                         0.79588
# Dystopia_Residual                  3.60214
# dtype: object

# %%
fig,ax=plt.subplots(figsize=(35,8))
sns.barplot(data=df_2015,x="Region",y="Happiness_Score")
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness_Score'>

# %%
#2015 * Mutluluk skoru en yüksek bölgelerin başında Kuzey Amerika ve Avustralya kıtası gelmektedir.En düşük skor ise Sahra Altı Afrika'dadadır.

# %%
df_2015.Region.value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# ### 1 ) En Yüksek Skorları Alan Ülkenler ve Bölgeler

# %%
df_2015
# Out:
#          Country                           Region  Happiness_Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  Standard_Error  GDP_per_Capita   Family   Healty  \
# 0              7.587         0.03411         1.39651  1.34951  0.94143
# ...

# %%
#En yüksek gayri safi yurtiçi hasılaya sahip ülke Katar.
df_2015[df_2015.GDP_per_Capita==df_2015.GDP_per_Capita.max()]
# Out:
#    Country                           Region  Happiness_Rank  Happiness_Score  \
# 27   Qatar  Middle East and Northern Africa              28            6.611
#
#     Standard_Error  GDP_per_Capita  Family   Healty  Freedom  \
# 27         0.06257         1.69042  1.0786  0.79733   0.6404
#
#     Trust_to_Goverment  Generosity  Dystopia_Residual
# 27             0.52208     0.32573            1.55674

# %%
#Mutlulukta aile faktörü en yüksek soru alan ülke İzlanda.
df_2015[df_2015.Family==df_2015.Family.max()]
# Out:
#    Country          Region  Happiness_Rank  Happiness_Score  Standard_Error  \
# 1  Iceland  Western Europe               2            7.561         0.04884
#
#    GDP_per_Capita   Family   Healty  Freedom  Trust_to_Goverment  Generosity  \
# 1         1.30232  1.40223  0.94784  0.62877             0.14145      0.4363
#
#    Dystopia_Residual
# 1            2.70201

# %%
#Yaşam beklentisi en çok skor alan ülke Singapur.
df_2015[df_2015.Healty==df_2015.Healty.max()]
# Out:
#       Country             Region  Happiness_Rank  Happiness_Score  \
# 23  Singapore  Southeastern Asia              24            6.798
#
#     Standard_Error  GDP_per_Capita  Family   Healty  Freedom  \
# 23          0.0378         1.52186    1.02  1.02525  0.54252
#
#     Trust_to_Goverment  Generosity  Dystopia_Residual
# 23              0.4921     0.31105            1.88501

# %%
#Özgürlük derecesi en yüksek ülke Norveç.
df_2015[df_2015.Freedom==df_2015.Freedom.max()]
# Out:
#   Country          Region  Happiness_Rank  Happiness_Score  Standard_Error  \
# 3  Norway  Western Europe               4            7.522          0.0388
#
#    GDP_per_Capita   Family   Healty  Freedom  Trust_to_Goverment  Generosity  \
# 3           1.459  1.33095  0.88521  0.66973             0.36503     0.34699
#
#    Dystopia_Residual
# 3            2.46531

# %%
#Hükümete güvenme skoru en yüksek ülke Ruanda.
df_2015[df_2015.Trust_to_Goverment==df_2015.Trust_to_Goverment.max()]
# Out:
#     Country              Region  Happiness_Rank  Happiness_Score  \
# 153  Rwanda  Sub-Saharan Africa             154            3.465
#
#      Standard_Error  GDP_per_Capita  Family   Healty  Freedom  \
# 153         0.03464         0.22208  0.7737  0.42864  0.59201
#
#      Trust_to_Goverment  Generosity  Dystopia_Residual
# 153             0.55191     0.22628            0.67042

# %%
#Cömertlik skoru en yüksek ülke Myanmar.
df_2015[df_2015.Generosity==df_2015.Generosity.max()]
# Out:
#      Country             Region  Happiness_Rank  Happiness_Score  \
# 128  Myanmar  Southeastern Asia             129            4.307
#
#      Standard_Error  GDP_per_Capita   Family   Healty  Freedom  \
# 128         0.04351         0.27108  0.70905  0.48246  0.44017
#
#      Trust_to_Goverment  Generosity  Dystopia_Residual
# 128             0.19034     0.79588            1.41805

# %%
df_2015[df_2015.Dystopia_Residual==df_2015.Dystopia_Residual.max()]
# Out:
#    Country                       Region  Happiness_Rank  Happiness_Score  \
# 13  Mexico  Latin America and Caribbean              14            7.187
#
#     Standard_Error  GDP_per_Capita   Family   Healty  Freedom  \
# 13         0.04176         1.02054  0.91451  0.81444  0.48181
#
#     Trust_to_Goverment  Generosity  Dystopia_Residual
# 13             0.21312     0.14074            3.60214

# %% [markdown]
# ## 2 ) 2015-2016 ile 2016-2017 raporları arasında ülke sıralamaları veya puanları nasıl değişti?

# %%
df_2015
# Out:
#          Country                           Region  Happiness_Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  GDP_per_Capita   Family   Healty  Freedom  \
# 0              7.587         1.39651  1.34951  0.94143  0.66557
# ...

# %%
df_2016=df_2016.drop(columns=["Lower Confidence Interval","Upper Confidence Interval"],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13100/1824418707.py in <module>
# ----> 1 df_2016=df_2016.drop(columns=["Lower Confidence Interval","Upper Confidence Interval"],axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df_2016=df_2016.rename(columns={"Happiness Rank":"Happiness_Rank","Happiness Score":"Happiness_Score","Standard Error":"Standard_Error",
                                "GDP":"GDP_per_Capita","Health (Life Expectancy)":"Healty","Trust (Government Corruption)":"Trust_to_Goverment","Dystopia Residual":"Dystopia_Residual"})

# %%
df_2016
# Out:
#          Country                           Region  Happiness_Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness_Score  Economy (GDP per Capita)   Family   Healty  Freedom  \
# 0              7.526                   1.44178  1.16374  0.79504  0.57941
# ...

# %%
df_2017=df_2017.drop(columns=["Whisker.high","Whisker.low"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13100/3052006643.py in <module>
# ----> 1 df_2017=df_2017.drop(columns=["Whisker.high","Whisker.low"])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df_2017=df_2017.rename(columns={"Happiness.Rank":"Happiness_Rank","Happiness.Score":"Happiness_Score","Standard Error":"Standard_Error",
                                "Economy..GDP.per.Capita.":"GDP_per_Capita","Health..Life.Expectancy.":"Healty","Trust..Government.Corruption.":"Trust_to_Goverment","Dystopia.Residual":"Dystopia_Residual"})

# %%
df_2017
# Out:
#                       Country  Happiness_Rank  Happiness_Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP_per_Capita    Family    Healty   Freedom  Generosity  \
# 0          1.616463  1.533524  0.796667  0.635423    0.362012
# 1          1.482383  1.551122  0.792566  0.626007    0.355280
# ...

# %%
region=[]
for i in range(0,155):
    region.append(" ")

# %%
for i in range(0,158):
    
    for j in range(0,155):
        
        if df_2015["Country"][i]==df_2017["Country"][j]:
            region[j]=df_2015["Region"][i]

# %%
df_2017["Region"]=region

# %%
df_2017[df_2017["Region"]==" "]
# Out:
#                       Country  Happiness_Rank  Happiness_Score  \
# 32   Taiwan Province of China              33            6.422
# 49                     Belize              50            5.956
# 70    Hong Kong S.A.R., China              71            5.472
# 92                    Somalia              93            5.151
# 110                   Namibia             111            4.574
# 146               South Sudan             147            3.591
#
#      GDP_per_Capita    Family    Healty   Freedom  Generosity  \
# 32         1.433627  1.384565  0.793984  0.361467    0.258360
# 49         0.907975  1.081418  0.450192  0.547509    0.240016
# 70         1.551675  1.262791  0.943062  0.490969    0.374466
# 92         0.022643  0.721151  0.113989  0.602127    0.291631
# 110        0.964434  1.098471  0.338612  0.520304    0.077134
# 146        0.397249  0.601323  0.163486  0.147062    0.285671
#
#      Trust_to_Goverment  Dystopia_Residual Region
# ...

# %%
df_2017["Region"][32]="Eastern Asia"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/1564117221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017["Region"][32]="Eastern Asia"

# %%
df_2017["Region"][49]="Latin America and Caribbean"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/805826971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017["Region"][49]="Latin America and Caribbean"

# %%
df_2017["Region"][70]="Eastern Asia"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/1323885187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017["Region"][70]="Eastern Asia"

# %%
df_2017["Region"][92]="Sub-Saharan Africa"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/3195867135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017["Region"][92]="Sub-Saharan Africa"

# %%
df_2017["Region"][110]="Southeastern Asia"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/3794984552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017["Region"][110]="Southeastern Asia"

# %%
df_2017["Region"][146]="Middle East and Northern Africa"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/1934704809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017["Region"][146]="Middle East and Northern Africa"

# %%
df_2017
# Out:
#                       Country  Happiness_Rank  Happiness_Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP_per_Capita    Family    Healty   Freedom  Generosity  \
# 0          1.616463  1.533524  0.796667  0.635423    0.362012
# 1          1.482383  1.551122  0.792566  0.626007    0.355280
# ...

# %%
half_df=df_2015[["Country","Region","Happiness_Rank"]]

# %%
half_df.rename(columns={"Happiness_Rank":"Rank_2015"})
# Out:
#          Country                           Region  Rank_2015
# 0    Switzerland                   Western Europe          1
# 1        Iceland                   Western Europe          2
# 2        Denmark                   Western Europe          3
# 3         Norway                   Western Europe          4
# 4         Canada                    North America          5
# ..           ...                              ...        ...
# 153       Rwanda               Sub-Saharan Africa        154
# 154        Benin               Sub-Saharan Africa        155
# 155        Syria  Middle East and Northern Africa        156
# 156      Burundi               Sub-Saharan Africa        157
# 157         Togo               Sub-Saharan Africa        158
#
# [158 rows x 3 columns]

# %%
rank_2016=[]
for i in range(0,158):
    rank_2016.append(" ")

# %%
for i in range(0,158):
    
    for j in range(0,157):
        
        if half_df["Country"][i]==df_2016["Country"][j]:
            rank_2016[i]=j+1

# %%
half_df["Rank_2016"]=rank_2016
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/3087475312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   half_df["Rank_2016"]=rank_2016

# %%
rank_2017=[]
for i in range(0,158):
    rank_2017.append(" ")

# %%
for i in range(0,158):
    
    for j in range(0,155):
        
        if half_df["Country"][i]==df_2017["Country"][j]:
            rank_2017[i]=j+1

# %%
half_df["Rank_2017"]=rank_2017
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/1780894334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   half_df["Rank_2017"]=rank_2017

# %%
half_df
# Out:
#          Country                           Region  Happiness_Rank Rank_2016  \
# 0    Switzerland                   Western Europe               1         2
# 1        Iceland                   Western Europe               2         3
# 2        Denmark                   Western Europe               3         1
# 3         Norway                   Western Europe               4         4
# 4         Canada                    North America               5         6
# ..           ...                              ...             ...       ...
# 153       Rwanda               Sub-Saharan Africa             154       152
# 154        Benin               Sub-Saharan Africa             155       153
# 155        Syria  Middle East and Northern Africa             156       156
# 156      Burundi               Sub-Saharan Africa             157       157
# 157         Togo               Sub-Saharan Africa             158       155
#
#     Rank_2017
# 0           4
# 1           3
# ...

# %%
df_2015[df_2015.Country=="Turkey"]
# Out:
#    Country                           Region  Happiness_Rank  Happiness_Score  \
# 75  Turkey  Middle East and Northern Africa              76            5.332
#
#     GDP_per_Capita   Family   Healty  Freedom  Trust_to_Goverment  Generosity  \
# 75         1.06098  0.94632  0.73172  0.22815             0.15746     0.12253
#
#     Dystopia_Residual
# 75            2.08528

# %%
df_2016[df_2016.Country=="Turkey"]
# Out:
#    Country                           Region  Happiness_Rank  Happiness_Score  \
# 77  Turkey  Middle East and Northern Africa              78            5.389
#
#     Economy (GDP per Capita)   Family   Healty  Freedom  Trust_to_Goverment  \
# 77                   1.16492  0.87717  0.64718  0.23889             0.12348
#
#     Generosity  Dystopia_Residual
# 77     0.04707            2.29074

# %%
df_2017[df_2017.Country=="Turkey"]
# Out:
#    Country  Happiness_Rank  Happiness_Score  GDP_per_Capita    Family  \
# 68  Turkey              69              5.5        1.198274  1.337753
#
#       Healty   Freedom  Generosity  Trust_to_Goverment  Dystopia_Residual  \
# 68  0.637606  0.300741    0.046693            0.099672           1.879278
#
#                              Region
# 68  Middle East and Northern Africa

# %%
half_df[half_df.Country=="Turkey"]
# Out:
#    Country                           Region  Happiness_Rank Rank_2016  \
# 75  Turkey  Middle East and Northern Africa              76        78
#
#    Rank_2017
# 75        69

# %%
half_df[half_df.Rank_2017==69]
# Out:
#    Country                           Region  Happiness_Rank Rank_2016  \
# 75  Turkey  Middle East and Northern Africa              76        78
#
#    Rank_2017
# 75        69

# %%
half_df.rename(columns={"Happiness_Rank":"Rank_2015"},inplace=True)
# Out:
# C:\Users\mehme\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
half_df
# Out:
#          Country                           Region  Rank_2015 Rank_2016  \
# 0    Switzerland                   Western Europe          1         2
# 1        Iceland                   Western Europe          2         3
# 2        Denmark                   Western Europe          3         1
# 3         Norway                   Western Europe          4         4
# 4         Canada                    North America          5         6
# ..           ...                              ...        ...       ...
# 153       Rwanda               Sub-Saharan Africa        154       152
# 154        Benin               Sub-Saharan Africa        155       153
# 155        Syria  Middle East and Northern Africa        156       156
# 156      Burundi               Sub-Saharan Africa        157       157
# 157         Togo               Sub-Saharan Africa        158       155
#
#     Rank_2017
# 0           4
# 1           3
# 2           2
# 3           1
# 4           7
# ..        ...
# ...

# %% [markdown]
# ### 2015-2016 Yılları Arasında Sıralaması En Çok Değişen Ülkeler

# %%
half_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 0 to 157
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    154 non-null    object
#  1   Region     154 non-null    object
#  2   Rank_2015  154 non-null    int64
#  3   Rank_2016  154 non-null    object
#  4   Rank_2017  154 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 11.3+ KB

# %%
half_df[half_df.Rank_2016==" "]
# Out:
#                       Country                           Region  Rank_2015  \
# 21                       Oman  Middle East and Northern Africa         22
# 90          Somaliland region               Sub-Saharan Africa         91
# 93                 Mozambique               Sub-Saharan Africa         94
# 96                    Lesotho               Sub-Saharan Africa         97
# 100                 Swaziland               Sub-Saharan Africa        101
# 125                  Djibouti               Sub-Saharan Africa        126
# 147  Central African Republic               Sub-Saharan Africa        148
#
#     Rank_2016 Rank_2017
# 21
# 90
# 93                  113
# 96                  139
# 100
# 125
# 147                 155

# %%
half_df.drop([21,90,100,125],inplace=True)
# Out:
# C:\Users\mehme\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#2016 yılında olmayan verileri drop işlemine sokacağım.

# %%
df_2015_to_2016=half_df.copy()

# %%
df_2015_to_2016.drop([93,96,147],inplace=True)

# %%
df_2015_to_2016["Rank_2016"]=df_2015_to_2016["Rank_2016"].astype("int64")

# %%
diff_15_16=df_2015_to_2016["Rank_2015"]-df_2015_to_2016["Rank_2016"]

# %%
half_df["2015_to_2016"]=diff_15_16
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/1021479957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   half_df["2015_to_2016"]=diff_15_16

# %%
half_df
# Out:
#          Country                           Region  Rank_2015 Rank_2016  \
# 0    Switzerland                   Western Europe          1         2
# 1        Iceland                   Western Europe          2         3
# 2        Denmark                   Western Europe          3         1
# 3         Norway                   Western Europe          4         4
# 4         Canada                    North America          5         6
# ..           ...                              ...        ...       ...
# 153       Rwanda               Sub-Saharan Africa        154       152
# 154        Benin               Sub-Saharan Africa        155       153
# 155        Syria  Middle East and Northern Africa        156       156
# 156      Burundi               Sub-Saharan Africa        157       157
# 157         Togo               Sub-Saharan Africa        158       155
#
#     Rank_2017  2015_to_2016
# 0           4          -1.0
# 1           3          -1.0
# ...

# %% [markdown]
# ## 2015-2016 Mutluluk Sıralaması Değişimi

# %%
half_df.sort_values(by="2015_to_2016",ascending=False).head(10)
# Out:
#        Country                           Region  Rank_2015 Rank_2016  \
# 67     Algeria  Middle East and Northern Africa         68        38
# 88      Latvia       Central and Eastern Europe         89        68
# 132   Cameroon               Sub-Saharan Africa        133       114
# 85     Romania       Central and Eastern Europe         86        71
# 131  Sri Lanka                    Southern Asia        132       117
# 134      Egypt  Middle East and Northern Africa        135       120
# 141    Senegal               Sub-Saharan Africa        142       128
# 120      Nepal                    Southern Asia        121       107
# 60    Malaysia                Southeastern Asia         61        47
# 103    Hungary       Central and Eastern Europe        104        91
#
#     Rank_2017  2015_to_2016 2016_to_2017
# 67         53          30.0          -15
# 88         54          21.0           14
# 132       107          19.0            7
# ...

# %%
#2015-2016 yılları arasında mutluluk sıralaması en çok artan ilk 10 ülke

# %%
diff_16_17=[]

# %%
df_2016_to_2017=half_df.copy()

# %%
half_df[half_df["Rank_2017"]==" "]
# Out:
#        Country                       Region  Rank_2015 Rank_2016 Rank_2017  \
# 37      Taiwan                 Eastern Asia         38        35
# 39    Suriname  Latin America and Caribbean         40        40
# 71   Hong Kong                 Eastern Asia         72        75
# 98        Laos            Southeastern Asia         99       102
# 139    Comoros           Sub-Saharan Africa        140       138
#
#      2015_to_2016
# 37            3.0
# 39            0.0
# 71           -3.0
# 98           -3.0
# 139           2.0

# %%
df_2016_to_2017.drop([37,39,71,98,139],inplace=True)

# %%
df_2016_to_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 157
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       149 non-null    object
#  1   Region        149 non-null    object
#  2   Rank_2015     149 non-null    int64
#  3   Rank_2016     149 non-null    object
#  4   Rank_2017     149 non-null    int64
#  5   2015_to_2016  146 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 8.1+ KB

# %%
df_2016_to_2017["Rank_2017"]=df_2016_to_2017["Rank_2017"].astype("int64")

# %%
df_2016_to_2017[df_2016_to_2017["Rank_2016"]==" "]
# Out:
#                       Country              Region  Rank_2015 Rank_2016  \
# 93                 Mozambique  Sub-Saharan Africa         94
# 96                    Lesotho  Sub-Saharan Africa         97
# 147  Central African Republic  Sub-Saharan Africa        148
#
#      Rank_2017  2015_to_2016
# 93         113           NaN
# 96         139           NaN
# 147        155           NaN

# %%
df_2016_to_2017.drop([93,96,147],inplace=True)

# %%
diff_16_17=df_2016_to_2017["Rank_2016"]-df_2016_to_2017["Rank_2017"]

# %%
half_df["2016_to_2017"]=diff_16_17
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/3752063296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   half_df["2016_to_2017"]=diff_16_17

# %%
half_df
# Out:
#          Country                           Region  Rank_2015 Rank_2016  \
# 0    Switzerland                   Western Europe          1         2
# 1        Iceland                   Western Europe          2         3
# 2        Denmark                   Western Europe          3         1
# 3         Norway                   Western Europe          4         4
# 4         Canada                    North America          5         6
# ..           ...                              ...        ...       ...
# 153       Rwanda               Sub-Saharan Africa        154       152
# 154        Benin               Sub-Saharan Africa        155       153
# 155        Syria  Middle East and Northern Africa        156       156
# 156      Burundi               Sub-Saharan Africa        157       157
# 157         Togo               Sub-Saharan Africa        158       155
#
#     Rank_2017  2015_to_2016 2016_to_2017
# 0           4          -1.0           -2
# ...

# %% [markdown]
# ### 2016-2017 Mutluluk Sıralaması Değişimi

# %%
half_df.sort_values(by="2016_to_2017",ascending=False).head(10)
# Out:
#           Country                           Region  Rank_2015 Rank_2016  \
# 133      Bulgaria       Central and Eastern Europe        134       129
# 134         Egypt  Middle East and Northern Africa        135       120
# 103       Hungary       Central and Eastern Europe        104        91
# 142         Gabon               Sub-Saharan Africa        143       134
# 112  South Africa               Sub-Saharan Africa        113       116
# 88         Latvia       Central and Eastern Europe         89        68
# 85        Romania       Central and Eastern Europe         86        71
# 152   Afghanistan                    Southern Asia        153       154
# 104      Honduras      Latin America and Caribbean        105       104
# 86         Serbia       Central and Eastern Europe         87        86
#
#     Rank_2017  2015_to_2016 2016_to_2017
# 133       105           5.0           24
# 134       104          15.0           16
# 103        75          13.0           16
# ...

# %%
#2016-2017 yılları arasında mutluluk sıralaması en çok artan ilk 10 ülke

# %%
####################################################

# %%
df_2018
# Out:
#      Happiness_Rank                   Country  Happiness_Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      GDP_per_Capita  Social_Support  Healty  Freedom  Generosity
# 0             1.305           1.592   0.874    0.681       0.202
# 1             1.456           1.582   0.861    0.686       0.286
# ...

# %%
df_2018=df_2018.rename(columns={"Overall rank":"Happiness_Rank","Score":"Happiness_Score","Standard Error":"Standard_Error","Country or region":"Country","Social support":"Social_Support",
                                "Freedom to make life choices":"Freedom","GDP per capita":"GDP_per_Capita","Healthy life expectancy":"Healty","Trust..Government.Corruption.":"Trust_to_Goverment","Dystopia.Residual":"Dystopia_Residual"})

# %%
#################################################33

# %%
df_2019=df_2019.drop(columns=["Perceptions of corruption"])

# %%
df_2019=df_2019.rename(columns={"Overall rank":"Happiness_Rank","Score":"Happiness_Score","Country or region":"Country","Social support":"Social_Support",
                                "Freedom to make life choices":"Freedom","GDP per capita":"GDP_per_Capita","Healthy life expectancy":"Healty"})

# %%
df_2019
# Out:
#      Happiness_Rank                   Country  Happiness_Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      GDP_per_Capita  Social_Support  Healty  Freedom  Generosity
# 0             1.340           1.587   0.986    0.596       0.153
# 1             1.383           1.573   0.996    0.592       0.252
# ...

# %%
sns.barplot(data=df_2015.head(10),x="Happiness_Score",y="Country")
# Out:
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Country'>

# %%
sns.barplot(data=df_2016.head(10),x="Happiness_Score",y="Country")
# Out:
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Country'>

# %%
sns.barplot(data=df_2017.head(10),x="Happiness_Score",y="Country")
# Out:
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Country'>

# %%
df_2015
# Out:
#          Country                           Region  Happiness_Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  GDP_per_Capita   Family   Healty  Freedom  \
# 0              7.587         1.39651  1.34951  0.94143  0.66557
# ...

# %%
df_2017
# Out:
#                       Country  Happiness_Rank  Happiness_Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP_per_Capita    Family    Healty   Freedom  Generosity  \
# 0          1.616463  1.533524  0.796667  0.635423    0.362012
# 1          1.482383  1.551122  0.792566  0.626007    0.355280
# ...

# %%
region=[]
for i in range(0,155):
    region.append(" ")

# %%
for i in range(0,158):
    
    for j in range(0,155):
        
        if df_2015["Country"][i]==df_2017["Country"][j]:
            region[j]=df_2015["Region"][i]

# %%
df_yedek=df_2017.copy()

# %%
df_yedek
# Out:
#                       Country  Happiness_Rank  Happiness_Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP_per_Capita    Family    Healty   Freedom  Generosity  \
# 0          1.616463  1.533524  0.796667  0.635423    0.362012
# 1          1.482383  1.551122  0.792566  0.626007    0.355280
# ...

# %%
df_yedek["Region"]=region

# %%
df_yedek
# Out:
#                       Country  Happiness_Rank  Happiness_Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP_per_Capita    Family    Healty   Freedom  Generosity  \
# 0          1.616463  1.533524  0.796667  0.635423    0.362012
# 1          1.482383  1.551122  0.792566  0.626007    0.355280
# ...

# %%
df_yedek.isna().sum()
# Out:
# Country               0
# Happiness_Rank        0
# Happiness_Score       0
# GDP_per_Capita        0
# Family                0
# Healty                0
# Freedom               0
# Generosity            0
# Trust_to_Goverment    0
# Dystopia_Residual     0
# Region                0
# dtype: int64

# %%
df_yedek[df_yedek["Region"]==" "]
# Out:
#                      Country  Happiness_Rank  Happiness_Score  GDP_per_Capita  \
# 49                    Belize              50            5.956        0.907975
# 70   Hong Kong S.A.R., China              71            5.472        1.551675
# 92                   Somalia              93            5.151        0.022643
# 110                  Namibia             111            4.574        0.964434
# 146              South Sudan             147            3.591        0.397249
#
#        Family    Healty   Freedom  Generosity  Trust_to_Goverment  \
# 49   1.081418  0.450192  0.547509    0.240016            0.096581
# 70   1.262791  0.943062  0.490969    0.374466            0.293934
# 92   0.721151  0.113989  0.602127    0.291631            0.282410
# 110  1.098471  0.338612  0.520304    0.077134            0.093147
# 146  0.601323  0.163486  0.147062    0.285671            0.116794
#
#      Dystopia_Residual Region
# 49            2.631956
# 70            0.554633
# ...

# %%
df_yedek["Region"][32]="Eastern Asia"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/1030882581.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yedek["Region"][32]="Eastern Asia"

# %%
df_yedek["Region"][49]="Latin America and Caribbean"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/2291569562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yedek["Region"][49]="Latin America and Caribbean"

# %%
df_yedek["Region"][70]="Eastern Asia"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/2471546362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yedek["Region"][70]="Eastern Asia"

# %%
df_yedek["Region"][92]="Sub-Saharan Africa"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/610157319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yedek["Region"][92]="Sub-Saharan Africa"

# %%
df_yedek["Region"][110]="Southeastern Asia"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/3414654167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yedek["Region"][110]="Southeastern Asia"

# %%
df_yedek["Region"][146]="Middle East and Northern Africa"
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_13100/3894233210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yedek["Region"][146]="Middle East and Northern Africa"

# %%
df_2015.Region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df_2017=df_yedek

# %%
df_2017
# Out:
#                       Country  Happiness_Rank  Happiness_Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP_per_Capita    Family    Healty   Freedom  Generosity  \
# 0          1.616463  1.533524  0.796667  0.635423    0.362012
# 1          1.482383  1.551122  0.792566  0.626007    0.355280
# ...

# %%
fig,ax=plt.subplots(figsize=(35,8))
sns.barplot(data=df_2017,x="Region",y="Happiness_Score")
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness_Score'>

# %%
############################################################################################

# %% [markdown]
# ## Herhangi bir ülke mutlulukta önemli bir artış veya azalma yaşadı mı?

# %%
for i in range(0,158):
    
    for j in range(0,156):

# %%
df_diff=df_2019.copy()

# %%
diff=df_2019["Happiness_Score"]-df_2015["Happiness_Score"]

# %%
df_diff["Difference_of_Score"]=pd.DataFrame(data=diff)
df_diff=df_diff.drop(columns=["Happiness_Score"])

# %%
df_diff.max()
# Out:
# Happiness_Rank              156
# Country                Zimbabwe
# GDP_per_Capita            1.684
# Social_Support            1.624
# Healty                    1.141
# Freedom                   0.631
# Generosity                0.566
# Difference_of_Score       0.204
# dtype: object

# %%
df_diff[["Difference_of_Score"]].idxmax()
# Out:
# Difference_of_Score    93
# dtype: int64

# %%
df_diff["Country"][93]
# Out:
# 'Vietnam'

# %%
df_diff[["Difference_of_Score"]].idxmin()
# Out:
# Difference_of_Score    152
# dtype: int64

# %%
df_diff["Country"][152]
# Out:
# 'Tanzania'

# %%
df_diff.sort_values(by=["Difference_of_Score"], inplace=False)
# Out:
#      Happiness_Rank      Country  GDP_per_Capita  Social_Support  Healty  \
# 152             153     Tanzania           0.476           0.885   0.499
# 24               25       Taiwan           1.368           1.430   0.914
# 25               26        Chile           1.159           1.369   0.920
# 150             151        Yemen           0.287           1.163   0.463
# 153             154  Afghanistan           0.350           0.517   0.361
# ..              ...          ...             ...             ...     ...
# 90               91      Lebanon           0.987           1.224   0.815
# 91               92    Indonesia           0.931           1.203   0.660
# 0                 1      Finland           1.340           1.587   0.986
# 92               93        China           1.029           1.125   0.893
# 93               94      Vietnam           0.741           1.346   0.851
#
#      Freedom  Generosity  Difference_of_Score
# ...

# %%
df_yedek2=df_2019.copy()

# %%
df_yedek2["Difference_of_Score"]=df_diff

# %%
df_yedek2.sort_values(by=["Difference_of_Score"], inplace=False).head(10)
# Out:
#      Happiness_Rank                   Country  Happiness_Score  \
# 152             153                  Tanzania            3.231
# 24               25                    Taiwan            6.446
# 25               26                     Chile            6.444
# 150             151                     Yemen            3.380
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 151             152                    Rwanda            3.334
# 149             150                    Malawi            3.410
# 27               28              Saudi Arabia            6.375
# 26               27                 Guatemala            6.436
#
#      GDP_per_Capita  Social_Support  Healty  Freedom  Generosity  \
# 152           0.476           0.885   0.499    0.417       0.276
# 24            1.368           1.430   0.914    0.351       0.242
# 25            1.159           1.369   0.920    0.357       0.187
# ...

# %%
#Mutluluk skoru en çok düşen 10 ülke

# %%
df_diff.sort_values(by=["Difference_of_Score"], inplace=False).tail(156)
# Out:
#      Happiness_Rank      Country  GDP_per_Capita  Social_Support  Healty  \
# 152             153     Tanzania           0.476           0.885   0.499
# 24               25       Taiwan           1.368           1.430   0.914
# 25               26        Chile           1.159           1.369   0.920
# 150             151        Yemen           0.287           1.163   0.463
# 153             154  Afghanistan           0.350           0.517   0.361
# ..              ...          ...             ...             ...     ...
# 90               91      Lebanon           0.987           1.224   0.815
# 91               92    Indonesia           0.931           1.203   0.660
# 0                 1      Finland           1.340           1.587   0.986
# 92               93        China           1.029           1.125   0.893
# 93               94      Vietnam           0.741           1.346   0.851
#
#      Freedom  Generosity  Difference_of_Score
# ...
