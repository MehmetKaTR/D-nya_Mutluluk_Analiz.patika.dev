# %%
# %run happiness_analysis.ipynb
# Out:
# C:\Users\mehme\AppData\Local\Temp/ipykernel_19844/1564117221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017["Region"][32]="Eastern Asia"
# C:\Users\mehme\AppData\Local\Temp/ipykernel_19844/805826971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017["Region"][49]="Latin America and Caribbean"
# C:\Users\mehme\AppData\Local\Temp/ipykernel_19844/1323885187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ## Hangi ülkeler veya bölgeler genel mutlulukta ve mutluluğa katkıda bulunan altı faktörün her birinde en yüksek sırada yer alıyor ?

# %%
df_2015
# Out:
#          Country                           Region  Happiness_Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  GDP_per_Capita   Family   Healty  Freedom  \
# 0              7.587         1.39651  1.34951  0.94143  0.66557
# ...

# %%
df_2016
# Out:
#          Country                           Region  Happiness_Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness_Score  Economy (GDP per Capita)   Family   Healty  Freedom  \
# 0              7.526                   1.44178  1.16374  0.79504  0.57941
# ...

# %%
df_2017
# Out:
#                       Country  Happiness_Rank  Happiness_Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      GDP_per_Capita    Family    Healty   Freedom  Generosity  \
# 0          1.616463  1.533524  0.796667  0.635423    0.362012
# 1          1.482383  1.551122  0.792566  0.626007    0.355280
# ...

# %%
df_2018
# Out:
#      Happiness_Rank                   Country  Happiness_Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      GDP_per_Capita  Social_Support  Healty  Freedom  Generosity  \
# 0             1.305           1.592   0.874    0.681       0.202
# 1             1.456           1.582   0.861    0.686       0.286
# ...

# %%
df_2018.drop(columns=["Perceptions of corruption"],inplace=True)

# %%
df_2018
# Out:
#      Happiness_Rank                   Country  Happiness_Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      GDP_per_Capita  Social_Support  Healty  Freedom  Generosity
# 0             1.305           1.592   0.874    0.681       0.202
# 1             1.456           1.582   0.861    0.686       0.286
# ...

# %%
df_2019
# Out:
#      Happiness_Rank                   Country  Happiness_Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      GDP_per_Capita  Social_Support  Healty  Freedom  Generosity
# 0             1.340           1.587   0.986    0.596       0.153
# 1             1.383           1.573   0.996    0.592       0.252
# ...

# %%
big_df=pd.DataFrame(data=df_2015[["Country","Happiness_Score"]])
big_df.rename(columns={"Happiness_Score":"Score_of_2015"},inplace=True)

# %%
big_df
# Out:
#          Country  Score_of_2015
# 0    Switzerland          7.587
# 1        Iceland          7.561
# 2        Denmark          7.527
# 3         Norway          7.522
# 4         Canada          7.427
# ..           ...            ...
# 153       Rwanda          3.465
# 154        Benin          3.340
# 155        Syria          3.006
# 156      Burundi          2.905
# 157         Togo          2.839
#
# [158 rows x 2 columns]

# %%
score_2016=[]
score_2017=[]
score_2018=[]
score_2019=[]

for i in range(0,158):
    score_2016.append(" ")
    score_2017.append(" ")
    score_2018.append(" ")
    score_2019.append(" ")

# %%
for i in range(0,158):
    
    for j in range(0,157):
        if big_df["Country"][i]==df_2016["Country"][j]:
            score_2016[i]=df_2016["Happiness_Score"][j]
############################################################
for i in range(0,158):
    
    for j in range(0,155):
        if big_df["Country"][i]==df_2017["Country"][j]:
            score_2017[i]=df_2017["Happiness_Score"][j]
############################################################
for i in range(0,158):
    
    for j in range(0,156):
        if big_df["Country"][i]==df_2018["Country"][j]:
            score_2018[i]=df_2018["Happiness_Score"][j]
############################################################
for i in range(0,158):
    
    for j in range(0,156):
        if big_df["Country"][i]==df_2019["Country"][j]:
            score_2019[i]=df_2019["Happiness_Score"][j]

# %%
big_df["Score_of_2016"]=score_2016
big_df["Score_of_2017"]=score_2017
big_df["Score_of_2018"]=score_2018
big_df["Score_of_2019"]=score_2019

# %%
big_df
# Out:
#          Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 0    Switzerland          7.587         7.509         7.494         7.487
# 1        Iceland          7.561         7.501         7.504         7.495
# 2        Denmark          7.527         7.526         7.522         7.555
# 3         Norway          7.522         7.498         7.537         7.594
# 4         Canada          7.427         7.404         7.316         7.328
# ..           ...            ...           ...           ...           ...
# 153       Rwanda          3.465         3.515         3.471         3.408
# 154        Benin          3.340         3.484         3.657         4.141
# 155        Syria          3.006         3.069         3.462         3.462
# 156      Burundi          2.905         2.905         2.905         2.905
# 157         Togo          2.839         3.303         3.495         3.999
#
#     Score_of_2019
# 0            7.48
# 1           7.494
# 2             7.6
# ...

# %%
#Senelere göre ülkelerin mutluluk skorları.

# %%
big_df.sort_values(by="Score_of_2015",ascending=False).head(10)
# Out:
#        Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 0  Switzerland          7.587         7.509         7.494         7.487
# 1      Iceland          7.561         7.501         7.504         7.495
# 2      Denmark          7.527         7.526         7.522         7.555
# 3       Norway          7.522         7.498         7.537         7.594
# 4       Canada          7.427         7.404         7.316         7.328
# 5      Finland          7.406         7.413         7.469         7.632
# 6  Netherlands          7.378         7.339         7.377         7.441
# 7       Sweden          7.364         7.291         7.284         7.314
# 8  New Zealand          7.286         7.334         7.314         7.324
# 9    Australia          7.284         7.313         7.284         7.272
#
#   Score_of_2019
# 0          7.48
# 1         7.494
# 2           7.6
# 3         7.554
# 4         7.278
# 5         7.769
# 6         7.488
# 7         7.343
# 8         7.307
# ...

# %%
big_df[(big_df.Score_of_2016==" ")]
# Out:
#                       Country  Score_of_2015 Score_of_2016 Score_of_2017  \
# 21                       Oman          6.853
# 90          Somaliland region          5.057
# 93                 Mozambique          4.971                        4.55
# 96                    Lesotho          4.898                       3.808
# 100                 Swaziland          4.867
# 125                  Djibouti          4.369
# 147  Central African Republic          3.678                       2.693
#
#     Score_of_2018 Score_of_2019
# 21
# 90
# 93          4.417         4.466
# 96          3.808         3.802
# 100                       4.212
# 125
# 147         3.083         3.083

# %%
big_df.drop([21,90,93,96,100,125,147],inplace=True)

# %%
big_df[(big_df.Score_of_2017==" ")]
# Out:
#        Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 37      Taiwan          6.298         6.379                       6.441
# 39    Suriname          6.269         6.269
# 71   Hong Kong          5.474         5.458                        5.43
# 98        Laos          4.876         4.876                       4.623
# 139    Comoros          3.956         3.956
#
#     Score_of_2019
# 37          6.446
# 39
# 71           5.43
# 98          4.796
# 139         3.973

# %%
big_df.drop([37,39,71,98,139],inplace=True)

# %%
big_df[(big_df.Score_of_2018==" ")]
# Out:
#                 Country  Score_of_2015 Score_of_2016 Score_of_2017  \
# 40  Trinidad and Tobago          6.168         6.168         6.168
# 65         North Cyprus          5.695         5.771          5.81
#
#    Score_of_2018 Score_of_2019
# 40
# 65

# %%
big_df.drop([40,65],inplace=True)

# %%
big_df[(big_df.Score_of_2019==" ")]
# Out:
#        Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 92   Macedonia          5.007         5.121         5.175         5.185
# 117      Sudan          4.550         4.139         4.139         4.139
# 136     Angola          4.033         3.866         3.795         3.795
#
#     Score_of_2019
# 92
# 117
# 136

# %%
big_df.drop([92,117,136],inplace=True)

# %%
df_copy=big_df.copy()

# %%
pd.set_option('display.max_rows', df_copy.shape[0]+1)
print(df_copy)
# Out:
#                      Country  Score_of_2015 Score_of_2016 Score_of_2017  \
# 0                Switzerland          7.587         7.509         7.494
# 1                    Iceland          7.561         7.501         7.504
# 2                    Denmark          7.527         7.526         7.522
# 3                     Norway          7.522         7.498         7.537
# 4                     Canada          7.427         7.404         7.316
# 5                    Finland          7.406         7.413         7.469
# 6                Netherlands          7.378         7.339         7.377
# 7                     Sweden          7.364         7.291         7.284
# 8                New Zealand          7.286         7.334         7.314
# 9                  Australia          7.284         7.313         7.284
# 10                    Israel          7.278         7.267         7.213
# 11                Costa Rica          7.226         7.087         7.079
# ...

# %%
big_df.sort_values(by="Score_of_2016",ascending=False).head(10)
# Out:
#        Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 2      Denmark          7.527         7.526         7.522         7.555
# 0  Switzerland          7.587         7.509         7.494         7.487
# 1      Iceland          7.561         7.501         7.504         7.495
# 3       Norway          7.522         7.498         7.537         7.594
# 5      Finland          7.406         7.413         7.469         7.632
# 4       Canada          7.427         7.404         7.316         7.328
# 6  Netherlands          7.378         7.339         7.377         7.441
# 8  New Zealand          7.286         7.334         7.314         7.324
# 9    Australia          7.284         7.313         7.284         7.272
# 7       Sweden          7.364         7.291         7.284         7.314
#
#   Score_of_2019
# 2           7.6
# 0          7.48
# 1         7.494
# 3         7.554
# 5         7.769
# 4         7.278
# 6         7.488
# 8         7.307
# 9         7.228
# ...

# %%
big_df.sort_values(by="Score_of_2017",ascending=False).head(10)
# Out:
#        Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 3       Norway          7.522         7.498         7.537         7.594
# 2      Denmark          7.527         7.526         7.522         7.555
# 1      Iceland          7.561         7.501         7.504         7.495
# 0  Switzerland          7.587         7.509         7.494         7.487
# 5      Finland          7.406         7.413         7.469         7.632
# 6  Netherlands          7.378         7.339         7.377         7.441
# 4       Canada          7.427         7.404         7.316         7.328
# 8  New Zealand          7.286         7.334         7.314         7.324
# 7       Sweden          7.364         7.291         7.284         7.314
# 9    Australia          7.284         7.313         7.284         7.272
#
#   Score_of_2019
# 3         7.554
# 2           7.6
# 1         7.494
# 0          7.48
# 5         7.769
# 6         7.488
# 4         7.278
# 8         7.307
# 7         7.343
# ...

# %%
big_df.sort_values(by="Score_of_2018",ascending=False).head(10)
# Out:
#        Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 5      Finland          7.406         7.413         7.469         7.632
# 3       Norway          7.522         7.498         7.537         7.594
# 2      Denmark          7.527         7.526         7.522         7.555
# 1      Iceland          7.561         7.501         7.504         7.495
# 0  Switzerland          7.587         7.509         7.494         7.487
# 6  Netherlands          7.378         7.339         7.377         7.441
# 4       Canada          7.427         7.404         7.316         7.328
# 8  New Zealand          7.286         7.334         7.314         7.324
# 7       Sweden          7.364         7.291         7.284         7.314
# 9    Australia          7.284         7.313         7.284         7.272
#
#   Score_of_2019
# 5         7.769
# 3         7.554
# 2           7.6
# 1         7.494
# 0          7.48
# 6         7.488
# 4         7.278
# 8         7.307
# 7         7.343
# ...

# %%
big_df.sort_values(by="Score_of_2019",ascending=False).head(10)
# Out:
#         Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 5       Finland          7.406         7.413         7.469         7.632
# 2       Denmark          7.527         7.526         7.522         7.555
# 3        Norway          7.522         7.498         7.537         7.594
# 1       Iceland          7.561         7.501         7.504         7.495
# 6   Netherlands          7.378         7.339         7.377         7.441
# 0   Switzerland          7.587         7.509         7.494         7.487
# 7        Sweden          7.364         7.291         7.284         7.314
# 8   New Zealand          7.286         7.334         7.314         7.324
# 4        Canada          7.427         7.404         7.316         7.328
# 12      Austria          7.200         7.119         7.006         7.139
#
#    Score_of_2019
# 5          7.769
# 2            7.6
# 3          7.554
# 1          7.494
# 6          7.488
# 0           7.48
# 7          7.343
# ...

# %%
fig,ax=plt.subplots(figsize=(12,5))
sns.barplot(data=big_df[0:10].sort_values(by="Score_of_2016",ascending=False),x="Country",y="Score_of_2016");

# %%
fig,ax=plt.subplots(figsize=(12,5))
sns.barplot(data=big_df[0:10].sort_values(by="Score_of_2017",ascending=False),x="Country",y="Score_of_2017");

# %%
fig,ax=plt.subplots(figsize=(12,5))
sns.barplot(data=big_df[0:10].sort_values(by="Score_of_2018",ascending=False),x="Country",y="Score_of_2018");

# %%
fig,ax=plt.subplots(figsize=(12,5))
sns.barplot(data=big_df[0:10].sort_values(by="Score_of_2019",ascending=False),x="Country",y="Score_of_2019");

# %%
#2015-2019 yılları içerisinde mutluluk skorunun en yüksek olduğu ülkelerin çoğunluğu İskandinav ülkeleridir.

# %% [markdown]
# ## Herhangi bir ülke mutlulukta önemli bir artış veya azalma yaşadı mı?

# %%
diff_scores=[]

for i in range(0,158):
    diff_scores.append(" ")

# %%
diff_scores=big_df["Score_of_2019"]-big_df["Score_of_2015"]

# %%
big_df["Difference_Score"]=diff_scores

# %%
big_df.head(10)
# Out:
#        Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 0  Switzerland          7.587         7.509         7.494         7.487
# 1      Iceland          7.561         7.501         7.504         7.495
# 2      Denmark          7.527         7.526         7.522         7.555
# 3       Norway          7.522         7.498         7.537         7.594
# 4       Canada          7.427         7.404         7.316         7.328
# 5      Finland          7.406         7.413         7.469         7.632
# 6  Netherlands          7.378         7.339         7.377         7.441
# 7       Sweden          7.364         7.291         7.284         7.314
# 8  New Zealand          7.286         7.334         7.314         7.324
# 9    Australia          7.284         7.313         7.284         7.272
#
#   Score_of_2019 Differece_Score Difference_Score
# 0          7.48          -0.107           -0.107
# 1         7.494          -0.067           -0.067
# ...

# %%
big_df.sort_values(by="Difference_Score",ascending=False).head(10)
# Out:
#           Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 154         Benin          3.340         3.484         3.657         4.141
# 150   Ivory Coast          3.655         3.916          4.18         4.671
# 157          Togo          2.839         3.303         3.495         3.999
# 104      Honduras          4.788         4.871         5.181         5.504
# 151  Burkina Faso          3.587         3.739         4.032         4.424
# 103       Hungary          4.800         5.145         5.324          5.62
# 85        Romania          5.124         5.528         5.825         5.945
# 142         Gabon          3.896         4.121         4.465         4.758
# 144      Cambodia          3.819         3.907         4.168         4.433
# 149        Guinea          3.656         3.607         3.507         3.964
#
#     Score_of_2019 Difference_Score
# 154         4.883            1.543
# 150         4.944            1.289
# 157         4.085            1.246
# ...

# %%
#Her yıl verisi bulunan ülkeler arasında mutluluk skoru en çok artan 10 ülke.

# %%
big_df.sort_values(by="Difference_Score",ascending=True).head(10)
# Out:
#        Country  Score_of_2015 Score_of_2016 Score_of_2017 Score_of_2018  \
# 22   Venezuela          6.810         6.084          5.25         4.806
# 84      Zambia          5.129         4.795         4.514         4.377
# 114   Zimbabwe          4.610         4.193         3.875         3.692
# 118      Haiti          4.518         4.028         3.603         3.582
# 130     Malawi          4.292         4.156          3.97         3.587
# 127   Botswana          4.332         3.974         3.766          3.59
# 135      Yemen          4.077         3.724         3.593         3.355
# 15      Brazil          6.983         6.952         6.635         6.419
# 115    Liberia          4.571         3.622         3.533         3.495
# 13      Mexico          7.187         6.778         6.578         6.488
#
#     Score_of_2019 Difference_Score
# 22          4.707           -2.103
# 84          4.107           -1.022
# 114         3.663           -0.947
# ...

# %%
#Her yıl verisi bulunan ülkeler arasında mutluluk skoru en çok azalan 10 ülke.
